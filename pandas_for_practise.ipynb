# %% [markdown]
# **PANDAS**

# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":['rohan','pooja','diya','abhi'],
    "marks":[25,45,78,39],
    "city":['delhi','mumbai','chennai','goa']
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#     name  marks     city
# 0  rohan     25    delhi
# 1  pooja     45   mumbai
# 2   diya     78  chennai
# 3   abhi     39      goa

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_index_false.csv',index=False)

# %%
df.head(2)
# Out:
#     name  marks    city
# 0  rohan     25   delhi
# 1  pooja     45  mumbai

# %%
df.tail(1)
# Out:
#    name  marks city
# 3  abhi     39  goa

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   46.750000
# std    22.455512
# min    25.000000
# 25%    35.500000
# 50%    42.000000
# 75%    53.250000
# max    78.000000

# %%
train=pd.read_csv('train_details.csv')

# %%
train
# Out:
#     train no  speed     city
# 0      anjum     48    delhi
# 1     pritha    465   mumbai
# 2  diyashree    178  chennai
# 3   abhijeet    236      goa
# 4     sakshi    100   shimla

# %%
train['speed']
# Out:
# 0     48
# 1    465
# 2    178
# 3    236
# 4    100
# Name: speed, dtype: int64

# %%
train['speed'][0]
# Out:
# 48

# %%
train['speed'][0]=48
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_10244/1493945157.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['speed'][0]=48

# %%
train
# Out:
#     train no  speed     city
# 0      anjum     48    delhi
# 1     pritha    465   mumbai
# 2  diyashree    178  chennai
# 3   abhijeet    236      goa
# 4     sakshi    100   shimla

# %%
train.to_csv('train_details.csv',index=False)

# %%
train.index=['a','b','c','d','e']

# %%
train
# Out:
#     train no  speed     city
# a      anjum     48    delhi
# b     pritha    465   mumbai
# c  diyashree    178  chennai
# d   abhijeet    236      goa
# e     sakshi    100   shimla

# %%
ser=pd.Series(np.random.rand(20))

# %%
ser
# Out:
# 0     0.706226
# 1     0.204311
# 2     0.027763
# 3     0.103590
# 4     0.453828
# 5     0.241361
# 6     0.999769
# 7     0.995059
# 8     0.712239
# 9     0.386806
# 10    0.405828
# 11    0.616945
# 12    0.491995
# 13    0.437663
# 14    0.745201
# 15    0.821038
# 16    0.473949
# 17    0.999857
# 18    0.660115
# 19    0.388730
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
df1=pd.DataFrame(np.random.rand(150,4))

# %%
df1
# Out:
#             0         1         2         3
# 0    0.003185  0.605431  0.527886  0.221181
# 1    0.851628  0.114630  0.664887  0.991154
# 2    0.531189  0.953822  0.811708  0.064916
# 3    0.345047  0.639777  0.735099  0.263533
# 4    0.727471  0.443783  0.508992  0.330157
# ..        ...       ...       ...       ...
# 145  0.911282  0.002623  0.088062  0.465328
# 146  0.652150  0.159137  0.510046  0.826079
# 147  0.146768  0.142717  0.725276  0.539414
# 148  0.790371  0.481020  0.721852  0.901333
# 149  0.911835  0.927929  0.005313  0.809887
#
# [150 rows x 4 columns]

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.describe()
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     0.518753    0.493772    0.497114    0.456009
# std      0.296843    0.304707    0.294406    0.278175
# min      0.003185    0.002623    0.001470    0.000804
# 25%      0.245784    0.228422    0.215976    0.227408
# 50%      0.530525    0.505009    0.539342    0.446283
# 75%      0.787321    0.771450    0.738399    0.652891
# max      0.988216    0.998242    0.996181    0.996085

# %%
df1.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# dtype: object

# %%
df1[0][0]='hello'

# %%
df1.dtypes
# Out:
# 0     object
# 1    float64
# 2    float64
# 3    float64
# dtype: object

# %%
df1.head()
# Out:
#           0         1         2         3
# 0     hello  0.605431  0.527886  0.221181
# 1  0.851628  0.114630  0.664887  0.991154
# 2  0.531189  0.953822  0.811708  0.064916
# 3  0.345047  0.639777  0.735099  0.263533
# 4  0.727471  0.443783  0.508992  0.330157

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df1.columns
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df1.to_numpy()
# Out:
# array([['hello', 0.6054311641597486, 0.5278858427986486,
#         0.22118149055268643],
#        [0.8516284418849639, 0.11462962404805233, 0.6648874041756972,
#         0.9911536695646708],
#        [0.5311887016533321, 0.9538221071241038, 0.8117077158182217,
#         0.06491605565465786],
#        [0.3450468363881799, 0.6397772701698486, 0.7350987799387895,
#         0.2635330024448118],
#        [0.7274710413534753, 0.4437825491568026, 0.5089920255822649,
#         0.330156862099214],
#        [0.1768079782448302, 0.6761142452437323, 0.19662223255885813,
#         0.31882394773859046],
#        [0.22410016081894468, 0.10001330568145339, 0.743988112445497,
#         0.29578048722348016],
#        [0.6066624388793104, 0.49975106299117833, 0.36629250557563775,
#         0.5997877625292037],
#        [0.8912313849147169, 0.09128351689975867, 0.25021391700198425,
#         0.81435730207717],
#        [0.9235057205280346, 0.7312593075046523, 0.6073018171159709,
# ...

# %%
df1.T
# Out:
#         0         1         2         3         4         5         6    \
# 0     hello  0.851628  0.531189  0.345047  0.727471  0.176808    0.2241
# 1  0.605431   0.11463  0.953822  0.639777  0.443783  0.676114  0.100013
# 2  0.527886  0.664887  0.811708  0.735099  0.508992  0.196622  0.743988
# 3  0.221181  0.991154  0.064916  0.263533  0.330157  0.318824   0.29578
#
#         7         8         9    ...       140       141       142       143  \
# 0  0.606662  0.891231  0.923506  ...  0.403301  0.397768  0.763065  0.565744
# 1  0.499751  0.091284  0.731259  ...  0.182397  0.103511  0.898844  0.520964
# 2  0.366293  0.250214  0.607302  ...  0.659657  0.197982  0.540939   0.17458
# 3  0.599788  0.814357  0.560377  ...  0.009563  0.988795  0.343908  0.520176
#
#         144       145       146       147       148       149
# 0  0.247558  0.911282   0.65215  0.146768  0.790371  0.911835
# 1  0.961861  0.002623  0.159137  0.142717   0.48102  0.927929
# ...

# %%
df1.head()
# Out:
#           0         1         2         3
# 0     hello  0.605431  0.527886  0.221181
# 1  0.851628  0.114630  0.664887  0.991154
# 2  0.531189  0.953822  0.811708  0.064916
# 3  0.345047  0.639777  0.735099  0.263533
# 4  0.727471  0.443783  0.508992  0.330157

# %%
df1.sort_index(axis=0,ascending=False)
# Out:
#             0         1         2         3
# 149  0.911835  0.927929  0.005313  0.809887
# 148  0.790371  0.481020  0.721852  0.901333
# 147  0.146768  0.142717  0.725276  0.539414
# 146   0.65215  0.159137  0.510046  0.826079
# 145  0.911282  0.002623  0.088062  0.465328
# ..        ...       ...       ...       ...
# 4    0.727471  0.443783  0.508992  0.330157
# 3    0.345047  0.639777  0.735099  0.263533
# 2    0.531189  0.953822  0.811708  0.064916
# 1    0.851628  0.114630  0.664887  0.991154
# 0       hello  0.605431  0.527886  0.221181
#
# [150 rows x 4 columns]

# %%
df1.sort_index(axis=1,ascending=False)
# Out:
#             3         2         1         0
# 0    0.221181  0.527886  0.605431     hello
# 1    0.991154  0.664887  0.114630  0.851628
# 2    0.064916  0.811708  0.953822  0.531189
# 3    0.263533  0.735099  0.639777  0.345047
# 4    0.330157  0.508992  0.443783  0.727471
# ..        ...       ...       ...       ...
# 145  0.465328  0.088062  0.002623  0.911282
# 146  0.826079  0.510046  0.159137   0.65215
# 147  0.539414  0.725276  0.142717  0.146768
# 148  0.901333  0.721852  0.481020  0.790371
# 149  0.809887  0.005313  0.927929  0.911835
#
# [150 rows x 4 columns]

# %%
df1.head()
# Out:
#           0         1         2         3
# 0     hello  0.605431  0.527886  0.221181
# 1  0.851628  0.114630  0.664887  0.991154
# 2  0.531189  0.953822  0.811708  0.064916
# 3  0.345047  0.639777  0.735099  0.263533
# 4  0.727471  0.443783  0.508992  0.330157

# %%
df1[0]
# Out:
# 0         hello
# 1      0.851628
# 2      0.531189
# 3      0.345047
# 4      0.727471
#          ...
# 145    0.911282
# 146     0.65215
# 147    0.146768
# 148    0.790371
# 149    0.911835
# Name: 0, Length: 150, dtype: object

# %%
type(df1[0])
# Out:
# pandas.core.series.Series

# %%
df2=df1

# %%
df1[0][0]=64

# %%
df1
# Out:
#             0         1         2         3
# 0          64  0.605431  0.527886  0.221181
# 1    0.851628  0.114630  0.664887  0.991154
# 2    0.531189  0.953822  0.811708  0.064916
# 3    0.345047  0.639777  0.735099  0.263533
# 4    0.727471  0.443783  0.508992  0.330157
# ..        ...       ...       ...       ...
# 145  0.911282  0.002623  0.088062  0.465328
# 146   0.65215  0.159137  0.510046  0.826079
# 147  0.146768  0.142717  0.725276  0.539414
# 148  0.790371  0.481020  0.721852  0.901333
# 149  0.911835  0.927929  0.005313  0.809887
#
# [150 rows x 4 columns]

# %%
df1.loc[0,0]=456

# %%
df1
# Out:
#             0         1         2         3
# 0         456  0.605431  0.527886  0.221181
# 1    0.851628  0.114630  0.664887  0.991154
# 2    0.531189  0.953822  0.811708  0.064916
# 3    0.345047  0.639777  0.735099  0.263533
# 4    0.727471  0.443783  0.508992  0.330157
# ..        ...       ...       ...       ...
# 145  0.911282  0.002623  0.088062  0.465328
# 146   0.65215  0.159137  0.510046  0.826079
# 147  0.146768  0.142717  0.725276  0.539414
# 148  0.790371  0.481020  0.721852  0.901333
# 149  0.911835  0.927929  0.005313  0.809887
#
# [150 rows x 4 columns]

# %%
df1.drop(3 ,axis=1)
# Out:
#             0         1         2
# 0         456  0.605431  0.527886
# 1    0.851628  0.114630  0.664887
# 2    0.531189  0.953822  0.811708
# 3    0.345047  0.639777  0.735099
# 4    0.727471  0.443783  0.508992
# ..        ...       ...       ...
# 145  0.911282  0.002623  0.088062
# 146   0.65215  0.159137  0.510046
# 147  0.146768  0.142717  0.725276
# 148  0.790371  0.481020  0.721852
# 149  0.911835  0.927929  0.005313
#
# [150 rows x 3 columns]

# %%
df1.loc[[145,146],[0,1]]
# Out:
#             0         1
# 145  0.911282  0.002623
# 146   0.65215  0.159137

# %%
df1.loc[[0,1],:]
# Out:
#           0         1         2         3
# 0       456  0.605431  0.527886  0.221181
# 1  0.851628  0.114630  0.664887  0.991154

# %%
df1.loc[(df1[0]>0.6 )& (df1[0]<0.8)]
# Out:
#             0         1         2         3
# 4    0.727471  0.443783  0.508992  0.330157
# 7    0.606662  0.499751  0.366293  0.599788
# 13   0.682442  0.510267  0.610562  0.328130
# 19   0.660004  0.678601  0.613029  0.395537
# 20   0.639909  0.761916  0.150407  0.588564
# 21   0.787799  0.754615  0.706819  0.060076
# 30   0.723834  0.213601  0.597297  0.443919
# 35   0.681448  0.768090  0.559338  0.640870
# 37   0.708473  0.217022  0.012807  0.082163
# 39   0.749663  0.674269  0.814269  0.267316
# 40   0.663852  0.206572  0.217530  0.258464
# 44    0.71339  0.535715  0.108769  0.581683
# 65   0.650762  0.009836  0.795264  0.257119
# 68   0.732304  0.616059  0.635785  0.575287
# 70   0.701365  0.827434  0.012223  0.178495
# 73   0.782045  0.821028  0.771819  0.411375
# 77   0.723504  0.832134  0.995049  0.153999
# 79   0.627159  0.210686  0.951331  0.165790
# 85   0.714439  0.237841  0.836779  0.761307
# 89   0.709597  0.607333  0.580569  0.304436
# ...

# %%
df1.head(2)
# Out:
#           0         1         2         3
# 0       456  0.605431  0.527886  0.221181
# 1  0.851628  0.114630  0.664887  0.991154

# %%
df1.iloc[1,2]
# Out:
# 0.6648874041756972

# %%
df1.iloc[[0,1],[1,2]]
# Out:
#           1         2
# 0  0.605431  0.527886
# 1  0.114630  0.664887

# %%
df1.head(5)
# Out:
#           0         1         2         3
# 0       456  0.605431  0.527886  0.221181
# 1  0.851628  0.114630  0.664887  0.991154
# 2  0.531189  0.953822  0.811708  0.064916
# 3  0.345047  0.639777  0.735099  0.263533
# 4  0.727471  0.443783  0.508992  0.330157

# %%
df1.drop([3],axis=1)
# Out:
#             0         1         2
# 0         456  0.605431  0.527886
# 1    0.851628  0.114630  0.664887
# 2    0.531189  0.953822  0.811708
# 3    0.345047  0.639777  0.735099
# 4    0.727471  0.443783  0.508992
# ..        ...       ...       ...
# 145  0.911282  0.002623  0.088062
# 146   0.65215  0.159137  0.510046
# 147  0.146768  0.142717  0.725276
# 148  0.790371  0.481020  0.721852
# 149  0.911835  0.927929  0.005313
#
# [150 rows x 3 columns]

# %%
df1
# Out:
#             0         1         2         3
# 0         456  0.605431  0.527886  0.221181
# 1    0.851628  0.114630  0.664887  0.991154
# 2    0.531189  0.953822  0.811708  0.064916
# 3    0.345047  0.639777  0.735099  0.263533
# 4    0.727471  0.443783  0.508992  0.330157
# ..        ...       ...       ...       ...
# 145  0.911282  0.002623  0.088062  0.465328
# 146   0.65215  0.159137  0.510046  0.826079
# 147  0.146768  0.142717  0.725276  0.539414
# 148  0.790371  0.481020  0.721852  0.901333
# 149  0.911835  0.927929  0.005313  0.809887
#
# [150 rows x 4 columns]

# %%
df1.drop([3],axis=1,inplace=True)

# %%
df1
# Out:
#             0         1         2
# 0         456  0.605431  0.527886
# 1    0.851628  0.114630  0.664887
# 2    0.531189  0.953822  0.811708
# 3    0.345047  0.639777  0.735099
# 4    0.727471  0.443783  0.508992
# ..        ...       ...       ...
# 145  0.911282  0.002623  0.088062
# 146   0.65215  0.159137  0.510046
# 147  0.146768  0.142717  0.725276
# 148  0.790371  0.481020  0.721852
# 149  0.911835  0.927929  0.005313
#
# [150 rows x 3 columns]

# %%
df1.head(5)
# Out:
#           0         1         2
# 0       456  0.605431  0.527886
# 1  0.851628  0.114630  0.664887
# 2  0.531189  0.953822  0.811708
# 3  0.345047  0.639777  0.735099
# 4  0.727471  0.443783  0.508992

# %%
df1.drop([2])
# Out:
#             0         1         2
# 0         456  0.605431  0.527886
# 1    0.851628  0.114630  0.664887
# 3    0.345047  0.639777  0.735099
# 4    0.727471  0.443783  0.508992
# 5    0.176808  0.676114  0.196622
# ..        ...       ...       ...
# 145  0.911282  0.002623  0.088062
# 146   0.65215  0.159137  0.510046
# 147  0.146768  0.142717  0.725276
# 148  0.790371  0.481020  0.721852
# 149  0.911835  0.927929  0.005313
#
# [149 rows x 3 columns]

# %%
df1.reset_index(drop=True,inplace=True)

# %%
df1.head(3)
# Out:
#           0         1         2
# 0       456  0.605431  0.527886
# 1  0.851628  0.114630  0.664887
# 2  0.531189  0.953822  0.811708

# %%
df1[1].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: 1, Length: 150, dtype: bool

# %%
df1.loc[2]=None

# %%
df1
# Out:
#             0         1         2
# 0         456  0.605431  0.527886
# 1    0.851628  0.114630  0.664887
# 2        None       NaN       NaN
# 3    0.345047  0.639777  0.735099
# 4    0.727471  0.443783  0.508992
# ..        ...       ...       ...
# 145  0.911282  0.002623  0.088062
# 146   0.65215  0.159137  0.510046
# 147  0.146768  0.142717  0.725276
# 148  0.790371  0.481020  0.721852
# 149  0.911835  0.927929  0.005313
#
# [150 rows x 3 columns]

# %%
df1.loc[:,[2]]=46

# %%
df1
# Out:
#             0         1   2
# 0         456  0.605431  46
# 1    0.851628  0.114630  46
# 2        None       NaN  46
# 3    0.345047  0.639777  46
# 4    0.727471  0.443783  46
# ..        ...       ...  ..
# 145  0.911282  0.002623  46
# 146   0.65215  0.159137  46
# 147  0.146768  0.142717  46
# 148  0.790371  0.481020  46
# 149  0.911835  0.927929  46
#
# [150 rows x 3 columns]

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Batman'],
                   "toy": [np.nan, np.nan, np.nan],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df.head()
# Out:
#      name  toy       born
# 0  Alfred  NaN        NaT
# 1  Batman  NaN 1940-04-25
# 2  Batman  NaN        NaT

# %%
df.dropna(how='all',axis=1)
# Out:
#      name       born
# 0  Alfred        NaT
# 1  Batman 1940-04-25
# 2  Batman        NaT

# %%
df.drop_duplicates(subset='name')
# Out:
#      name  toy       born
# 0  Alfred  NaN        NaT
# 1  Batman  NaN 1940-04-25

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     0 non-null      float64
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 124.0+ bytes

# %%
df['name'].value_counts(dropna=False)
# Out:
# Batman    2
# Alfred    1
# Name: name, dtype: int64

# %%
df.notnull()
# Out:
#    name    toy   born
# 0  True  False  False
# 1  True  False   True
# 2  True  False  False

# %%
df.isnull()
# Out:
#     name   toy   born
# 0  False  True   True
# 1  False  True  False
# 2  False  True   True

# %%
data = pd.read_excel('newtraindetals.xlsx')

# %%
data
# Out:
#     train no  speed     city
# 0      anjum     48    delhi
# 1     pritha    465   mumbai
# 2  diyashree    178  chennai
# 3   abhijeet    236      goa
# 4     sakshi    100   shimla

# %%
data1=pd.read_excel('newtraindetals.xlsx',sheet_name='Sheet2')

# %%
data1
# Out:
#        NAME2  speed2    city2
# 0      anjum     789    delhi
# 1     pritha     456   mumbai
# 2  diyashree     456  chennai
# 3   abhijeet     123      goa
# 4     sakshi     463   shimla

# %%
data1.iloc[0,2]='london'

# %%
data1
# Out:
#        NAME2  speed2    city2
# 0      anjum     789   london
# 1     pritha     456   mumbai
# 2  diyashree     456  chennai
# 3   abhijeet     123      goa
# 4     sakshi     463   shimla

# %%
data.to_excel('Workbook.xlsx', sheet_name="work1")

# %%
with pd.ExcelWriter('Workbook.xlsx') as writer:  
    data.to_excel(writer, sheet_name='Sheet_1')
    data1.to_excel(writer, sheet_name='Sheet_2')
